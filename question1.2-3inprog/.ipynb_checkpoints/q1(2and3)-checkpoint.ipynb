# %% [markdown]
# # Question 1(parts 2 and 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import os

# %%
dognition_agg= pd.read_excel("dognition_data_aggregated_by_dogid.xlsx")
display(dognition_agg)
# Out:
#                                      Dog ID  Total Tests Completed  \
# 0      fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1      fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2      fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3      fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4      fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
# ...                                     ...                    ...
# 17981  fdc235e0-7144-11e5-ba71-058fbc01cf0b                      7
# 17982  fdc23a68-7144-11e5-ba71-058fbc01cf0b                      1
# 17983  fdc23ba8-7144-11e5-ba71-058fbc01cf0b                     20
# 17984  fdc23e96-7144-11e5-ba71-058fbc01cf0b                      4
# 17985  fdc2417a-7144-11e5-ba71-058fbc01cf0b                      6
#
#        Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0            28.201076        40609.549167           0.004687
# ...

# %%
sns.scatterplot(data=dognition_agg, x='Total Tests Completed', y='Time diff between first and last game (days)')
# Out:
# <Axes: xlabel='Total Tests Completed', ylabel='Time diff between first and last game (days)'>

# %%
sns.scatterplot(data=dognition_agg, x='Total Tests Completed', y='Time diff between first and last game (minutes)')
# Out:
# <Axes: xlabel='Total Tests Completed', ylabel='Time diff between first and last game (minutes)'>
